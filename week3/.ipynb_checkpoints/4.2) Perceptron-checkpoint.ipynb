# %% [markdown]
# ## Perceptron

# %% [markdown]
# ### data generation

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

m = 100
v0 = 8*np.random.rand(m, 1)
v1 = 7*np.random.rand(m, 1) -4

h = 0.8*v0 + v1 -3

# %%
x0 = v0[np.where(h>=1)]
y0 = v1[np.where(h>=1)]

x1 = v0[np.where(h<-1)]
y1 = v1[np.where(h<-1)]

print(x0)
print(x0.shape)
# Out:
# [7.87106543 7.72334445 6.12169797 6.38523812 6.64239309 7.4655028
#  6.49827516 6.7187324  2.13665675 3.42364867 7.53515133 5.44727856
#  4.84433349 5.99451397 6.1912926  7.23237757 7.62343271 6.62147215
#  7.57896584 3.9050005  4.12863261 5.00656545 5.64710085 6.90246695
#  7.27483817 2.23064268 3.57127412 6.53672786 6.33278863 7.78090496
#  5.00054816 4.99247387 6.9866589  6.17065805 5.38926258 1.78967524
#  3.93534597 4.22855139]
# (38,)

# %%
plt.figure(figsize=(8, 7))
plt.plot(x0, y0, 'ro', alpha=0.4, label = 'C1')
plt.plot(x1, y1, 'bo', alpha=0.4, label='C0')
plt.legend(loc = 4, fontsize = 15)
plt.title('Classes for Perceptron', fontsize=15)
plt.xlabel(r'$v_0$', fontsize=15)
plt.ylabel(r'$v_1$', fontsize=15)
plt.show()
